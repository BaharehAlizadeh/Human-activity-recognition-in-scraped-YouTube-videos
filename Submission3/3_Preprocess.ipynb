# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
pip install pytictoc
# Out:
# Collecting pytictoc
#   Downloading https://files.pythonhosted.org/packages/17/fa/c60631a899d6bb370f58d4cd95162ec3c204cd3987f2d65bd7c6a3270dd5/pytictoc-1.5.1-py2.py3-none-any.whl
# Installing collected packages: pytictoc
# Successfully installed pytictoc-1.5.1

# %%
import numpy as np
import keras
import sklearn as sk
import cv2
from keras.applications.resnet import ResNet50
from keras.utils.vis_utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten
import pytictoc
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import glob
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
time_print = pytictoc.TicToc()
time_print.tic()
videos = []
labels_2d = []
num_frames = 100
frame_rate = 5
time_3d = []
time_2d = []
############################# Videos with label = 1
i=0
for path in glob.glob('/content/drive/My Drive/CSCE636/3_Video_Cutting/1/*.mp4'):
  
  vidcap = cv2.VideoCapture(path)
  fps = vidcap.get(cv2.CAP_PROP_FPS)
  success, image = vidcap.read()
  frames = []
  

  time = []
  count = 0  # control to have the same number of frames
  count_fps = 0
  while success:
    
    
    success, image = vidcap.read()
    count += 1
    if(type(image).__module__ == np.__name__):
      new_image = cv2.resize(image, (224,224), interpolation = cv2.INTER_AREA)
      
      frames.append(new_image)
      time.append(count_fps*(1/fps))
      count_fps += 1
      if count==num_frames:
        count_fps = 0
        print("Frames_", str(count),", video_", str(i), "Done, Time_Elapsed: ", str(round(time_print.tocvalue(),3)), " Seconds")
        videos.append(frames)
        time_3d.append(time)
        count = 0
        frames = []
        time = []

  if (count < num_frames):
    while (count > 0 and count <= num_frames):
      frames.append(new_image)    # if the number of frames is lower than the num_frames, repeat the last image to reach num_frames
      count +=1
      time.append(count_fps*(1/fps))
      count_fps += 1
      
    videos.append(frames)
    time_3d.append(time)
  
  i+=1
  print("Video_", str(i),"Done, Time_Elapsed: ", str(round(time_print.tocvalue(),3)), " Seconds")


videos_2d_len = len(videos)

############################# Videos with label = 0
i=0
for path in glob.glob('/content/drive/My Drive/CSCE636/3_Video_Cutting/0/*.mp4'):
  if(i == 219):
    break
  
  vidcap = cv2.VideoCapture(path)
  fps = vidcap.get(cv2.CAP_PROP_FPS)
  success, image = vidcap.read()
  frames = []
  
  time = []
  count = 0  # control to have the same number of frames
  count_fps = 0
  while success:
    
    success, image = vidcap.read()
    count += 1
    if(type(image).__module__ == np.__name__):
      new_image = cv2.resize(image, (224,224), interpolation = cv2.INTER_AREA)
    
      frames.append(new_image)
      time.append(count_fps*(1/fps))
      count_fps += 1
      if count==num_frames:
        count_fps = 0
        print("Frames_", str(count),", video_", str(i), "Done, Time_Elapsed: ", str(round(time_print.tocvalue(),3)), " Seconds")
        videos.append(frames)
        time_3d.append(time)
        count = 0
        frames = []
        time = []


  if (count < num_frames):
    while (count > 0 and count <= num_frames):
      frames.append(new_image)    # if the number of frames is lower than the num_frames, repeat the last image to reach num_frames
      count +=1
      time.append(count_fps*(1/fps))
      count_fps += 1
      
    videos.append(frames)
    time_3d.append(time)

  i+=1
  print("Video_", str(i),"Done, Time_Elapsed: ", str(round(time_print.tocvalue(),3)), " Seconds")

videos_3d = np.array(videos)

labels_2d = np.zeros((len(videos_3d),num_frames))
labels_2d[0:videos_2d_len,:] = 1

time_3d = np.array(time_3d)
# Out:
# Frames_ 100 , video_ 0 Done, Time_Elapsed:
Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  264.038  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  265.367  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  266.692  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  268.017  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  269.347  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  270.724  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  272.077  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  273.445  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  274.804  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  276.179  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  277.55  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  278.91  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  280.245  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  281.573  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  282.927  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  284.295  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  285.65  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  286.996  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  288.344  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  289.708  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  291.042  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  292.389  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  293.739  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  295.07  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  296.39  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  297.709  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  299.051  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  300.374  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  301.714  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  303.066  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  304.402  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  305.769  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  307.166  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  308.539  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  309.887  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  311.267  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  312.631  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  314.011  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  315.402  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  316.76  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  318.113  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  319.45  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  320.78  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  322.116  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  323.469  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  324.852  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  326.235  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  327.579  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  328.914  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  330.303  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  331.665  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  333.014  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  334.449  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  335.856  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  337.241  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  338.583  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  339.944  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  341.29  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  342.672  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  344.075  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  345.464  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  346.831  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  348.213  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  349.614  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  350.999  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  352.331  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  353.709  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  355.087  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  356.452  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  357.816  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  359.173  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  360.493  Seconds
# Frames_ 100 , video_ 2 Done, Time_Elapsed:  361.832  Seconds
# Video_ 3 Done, Time_Elapsed:  362.194  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  364.334  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  365.712  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  367.037  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  368.366  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  369.728  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  371.084  Seconds
# Frames_ 100 , video_ 3 Done, Time_Elapsed:  372.412  Seconds
# Video_ 4 Done, Time_Elapsed:  372.738  Seconds
# Video_ 5 Done, Time_Elapsed:  373.155  Seconds
# Video_ 6 Done, Time_Elapsed:  373.65  Seconds
# Video_ 7 Done, Time_Elapsed:  374.087  Seconds

# %%
#Correcting shapes of images
ind = list(np.random.randint(0,len(videos_3d)-1,size=len(videos_3d)))
videos_3d_temp = videos_3d[ind]
videos_2d_shuffled = np.reshape(videos_3d_temp, (-1,224,224,3))
videos_2d_shuffled = videos_2d_shuffled[:len(videos_2d_shuffled):frame_rate]

time_3d_temp = time_3d[ind]
time_2d_shuffled = np.reshape(time_3d_temp, (-1,1))
time_2d_shuffled = time_2d_shuffled[:len(time_2d_shuffled):frame_rate]
time_2d_shuffled = time_2d_shuffled.T[0]

labels_2d_temp = labels_2d[ind]
labels_2d_shuffled = labels_2d_temp.flatten()
labels_2d_shuffled = labels_2d_shuffled[:len(labels_2d_shuffled):frame_rate]

# %%
#Saving all the vidoes as npy formats to reduce time for reading video files
np.save("/content/drive/My Drive/CSCE636/3_Dataset/raw_data.npy", videos_2d_shuffled)
np.save("/content/drive/My Drive/CSCE636/3_Dataset/raw_label.npy", labels_2d_shuffled)
np.save("/content/drive/My Drive/CSCE636/3_Dataset/times.npy", time_2d_shuffled)

# %%
pip install pytictoc
# Out:
# Collecting pytictoc
#   Downloading https://files.pythonhosted.org/packages/d5/cf/87661e4a929be7023172b7684a704df8379d78a2ed1b86cc01a6cd32cd11/pytictoc-1.5.0-py2.py3-none-any.whl
# Installing collected packages: pytictoc
# Successfully installed pytictoc-1.5.0

# %%
np.shape(time_3d)
# Out:
# (295, 100)
